# %%
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests 
from tqdm import tqdm
import numpy as np

# %%
key='Iuowj7UW8R3d8WxSA%2Fh2wTsszZ1EZT22V%2FB%2BRBhNPW4bMCrxh0l89LSAmPjeCo1G%2FLjJTbmUbi%2FAM%2BL8Ae3cYQ%3D%3D'
url= 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19GenAgeCaseInfJson?pageNo=1&numOfRows=10&startCreateDt=202004020&endCreateDt=20201030&serviceKey={}'.format(key)

Age_gender=requests.get(url).content
dict= xmltodict.parse(Age_gender)
jsonString=json.dumps(dict['response']['body']['items'], ensure_ascii=False)
print(jsonString)
# Out:
# {"item": [{"confCase": "685", "confCaseRate": "2.6", "createDt": "2020-10-30 14:10:38.514", "criticalRate": "0", "death": "0", "deathRate": "0.00", "gubun": "0-9", "seq": "4336", "updateDt": "null"}, {"confCase": "1452", "confCaseRate": "5.5", "createDt": "2020-10-30 14:10:38.514", "criticalRate": "0", "death": "0", "deathRate": "0.00", "gubun": "10-19", "seq": "4335", "updateDt": "null"}, {"confCase": "5147", "confCaseRate": "19.51", "createDt": "2020-10-30 14:10:38.514", "criticalRate": "0", "death": "0", "deathRate": "0.00", "gubun": "20-29", "seq": "4334", "updateDt": "null"}, {"confCase": "3263", "confCaseRate": "12.37", "createDt": "2020-10-30 14:10:38.513", "criticalRate": "0.06", "death": "2", "deathRate": "0.43", "gubun": "30-39", "seq": "4333", "updateDt": "null"}, {"confCase": "3545", "confCaseRate": "13.44", "createDt": "2020-10-30 14:10:38.513", "criticalRate": "0.11", "death": "4", "deathRate": "0.86", "gubun": "40-49", "seq": "4332", "updateDt": "null"}, {"confCase": "
# ...

# %%
import requests, bs4
import pandas as pd
from lxml import html
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote

xmlUrl = 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19GenAgeCaseInfJson?'

My_API_Key = unquote('Iuowj7UW8R3d8WxSA%2Fh2wTsszZ1EZT22V%2FB%2BRBhNPW4bMCrxh0l89LSAmPjeCo1G%2FLjJTbmUbi%2FAM%2BL8Ae3cYQ%3D%3D')

queryParams = '?' + urlencode(    
    {
        quote_plus('ServiceKey') : My_API_Key,
        quote_plus('pageNo') : '1', 
        quote_plus('numOfRows') : '10', 
        quote_plus('startCreateDt') : '20200101', 
        quote_plus('endCreateDt') : '20201030' }       
)

response = requests.get(xmlUrl + queryParams).text.encode('utf-8')
xmlobj = bs4.BeautifulSoup(response, 'lxml-xml')

rows = xmlobj.findAll('item')

rowList = []
nameList = []
columnList = []

rowsLen = len(rows)
for i in range(0, rowsLen):
    columns = rows[i].find_all()
    
    columnsLen = len(columns)
    for j in range(0, columnsLen):
        if i == 0:
            nameList.append(columns[j].name) 
        eachColumn = columns[j].text
        columnList.append(eachColumn)
    rowList.append(columnList)
    columnList = []    

    
result = pd.DataFrame(rowList, columns=nameList)
print(result)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
key='Iuowj7UW8R3d8WxSA%2Fh2wTsszZ1EZT22V%2FB%2BRBhNPW4bMCrxh0l89LSAmPjeCo1G%2FLjJTbmUbi%2FAM%2BL8Ae3cYQ%3D%3D'
url= 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson?pageNo=1&numOfRows=10&startCreateDt=20200101&endCreateDt=20201030&serviceKey={}'.format(key)

page=requests.get(url)
soup=BeautifulSoup(page.content, "html.parser")

# %%
date=soup.find_all('createdt')
dates=[]
for n in date:
    a= n.get_text()
    dates.append(a)

accdef=soup.find_all('accdefrate')
accdefrate=[]
for n in accdef:
    a= n.get_text()
    accdefrate.append(a)
    
accexam=soup.find_all('accexamcompcnt')
accexamcompcnt=[]
for n in accexam:
    a= n.get_text()
    accexamcompcnt.append(a)
    
acc=soup.find_all('accexamcnt')
accexamcnt=[]
for n in acc:
    a= n.get_text()
    accexamcnt.append(a)
    
resutl=soup.find_all('resutlnegcnt')
resutlnegcnt=[]
for n in resutl:
    a= n.get_text()
    resutlnegcnt.append(a)
    
care=soup.find_all('carecnt')
carecnt=[]
for n in care:
    a= n.get_text()
    carecnt.append(a)

death=soup.find_all('deathcnt')
deathcnt=[]
for n in death:
    a= n.get_text()
    deathcnt.append(a)
    
update=soup.find_all('updatedt')
updatedt=[]
for n in update:
    a= n.get_text()
    updatedt.append(a)
    
exam=soup.find_all('examcnt')
examcnt=[]
for n in exam:
    a= n.get_text()
    examcnt.append(a)

clear=soup.find_all('clearcnt')
clearcnt=[]
for n in clear:
    a= n.get_text()
    clearcnt.append(a)
    
decide= soup.find_all('decidecnt')
decidecnt=[]
for n in decide:
    a= n.get_text()
    decidecnt.append(a)
    
state=soup.find_all('statetime')
statetime=[]
for n in state:
    a= n.get_text()
    statetime.append(a)

se=soup.find_all('seq')
seq=[]
for n in se:
    a= n.get_text()
    seq.append(a)   
    
stated= soup.find_all('statedt')
statedt=[]
for n in stated:
    a= n.get_text()
    statedt.append(a)
    
import pandas as pd

data_1=({'createdt':'등록일시분초','statedt':'기준일', 'statetime':'기준시간','decidecnt':'확진자 수','clearcnt':'격리해제 수',
      'examcnt':'검사진행 수','updatedt':'수정일시분초','deathcnt':'사망자 수', 'carecnt':'치료중 환자 수','resutlnegcnt':'결과 음성 수',
      'accexamcnt':'누적 검사수','accexamcompcnt':'누적 검사 완료수', 'accdefrate':'누적 환진률','seq':'감염현황 고유값'})
df_1= pd.DataFrame(data_1)
df_1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-f2312cb2c3f5> in <module>
#      88       'examcnt':'검사진행 수','updatedt':'수정일시분초','deathcnt':'사망자 수', 'carecnt':'치료중 환자 수','resutlnegcnt':'결과 음성 수',
#      89       'accexamcnt':'누적 검사수','accexamcompcnt':'누적 검사 완료수', 'accdefrate':'누적 환진률','seq':'감염현황 고유값'})
# ---> 90 df_1= pd.DataFrame(data_1)
#      91 df_1
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
# ...

# %%
date=soup.find_all('createdt')
dates=[]
for n in date:
    a= n.get_text()
    dates.append(a)

age= soup.find_all('gubun')
age_gender=[]
for n in age:
    a= n.get_text()
    age_gender.append(a)
    
conf=soup.find_all('confcase')
confcase=[]
for n in conf:
    a= n.get_text()
    confcase.append(a)
    
death=soup.find_all('death')
deaths=[]
for n in death:
    a= n.get_text()
    deaths.append(a)
    
seq_1=soup.find_all('seq')
seq=[]
for n in seq_1:
    a= n.get_text()
    seq.append(a)
    
deathr=soup.find_all('deathrate')
deathrate=[]
for n in deathr:
    a= n.get_text()
    deathrate.append(a)

critical=soup.find_all('criticalrate')
criticalrate=[]
for n in critical:
    a= n.get_text()
    criticalrate.append(a)
    
update=soup.find_all('updatedt')
updatedt=[]
for n in update:
    a= n.get_text()
    updatedt.append(a)
    
confcase=soup.find_all('confcaserate')
confcaserate=[]
for n in confcase:
    a= n.get_text()
    confcaserate.append(a)
    
import pandas as pd

data={'date': dates, 'updatedt':updatedt, 'confcase':confcase, 'confcaserate':confcaserate, 'gubun':age_gender, 'death':deaths, 
      'deathrate':deathrate, 'criticalrate':criticalrate, 'seq':seq}
df= pd.DataFrame(data)
df
# Out:
#                          date updatedt confcase confcaserate  gubun death  \
# 0     2020-10-30 14:10:38.514     null    [2.6]          2.6    0-9     0
# 1     2020-10-30 14:10:38.514     null    [5.5]          5.5  10-19     0
# 2     2020-10-30 14:10:38.514     null  [19.51]        19.51  20-29     0
# 3     2020-10-30 14:10:38.513     null  [12.37]        12.37  30-39     2
# 4     2020-10-30 14:10:38.513     null  [13.44]        13.44  40-49     4
# ...                       ...      ...      ...          ...    ...   ...
# 2240   2020-04-02 19:02:48.48           [12.62]        12.62  60-69    22
# 2241   2020-04-02 19:02:48.48            [6.65]         6.65  70-79    46
# 2242   2020-04-02 19:02:48.48            [4.52]         4.52  80 이상    82
# 2243   2020-04-02 19:02:48.48            [60.1]         60.1     여성    80
# 2244   2020-04-02 19:02:48.48            [39.9]         39.9     남성    82
#
#      deathrate criticalrate   seq
# 0         0.00            0  4336
# ...
